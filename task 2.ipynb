# %%
import pytz
from datetime import datetime
import plotly.express as px
import plotly.graph_objects as go
# ------------------------------
# Time Restriction (1PM–2PM IST)
# ------------------------------
ist = pytz.timezone("Asia/Kolkata")
current_time = datetime.now(ist)

if 13 <= current_time.hour < 14 and not result.empty:

    result_reset = result.reset_index()

    fig = px.bar(
        result_reset,
        x="Type",
        y=["Installs", "Revenue"],
        barmode="group",
        title="Average Installs and Revenue (Top 3 Categories)",
        labels={
            "value": "Average Value",
            "Type": "App Type",
            "variable": "Metric"
        },
        template="plotly_white"
    )

    fig.update_layout(
        xaxis_title="App Type (Free vs Paid)",
        yaxis_title="Average Value",
        legend_title="Metrics"
    )

    fig.show()

else:
    print("Graph visible only between 1 PM IST and 2 PM IST.")
# Out:
# Graph visible only between 1 PM IST and 2 PM IST.
